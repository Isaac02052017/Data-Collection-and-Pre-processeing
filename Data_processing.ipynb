# %% [markdown]
# # **Data Collection and Pre-processing**

# %% [markdown]
# **1. Hello, Data!**

# %%
import pandas as pd

# Load raw data
raw_df = pd.read_csv(r"D:\AI ML\Machine learning Programming\Lab 2\raw_transactions.csv")
raw_df.head(3)
# Out:
#                               Region                Country  Item Type  \
# 0       Middle East and North Africa             Azerbaijan     Snacks
# 1  Central America and the Caribbean                 Panama  Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe     Fruits
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              C  10/8/2014  535113847  10/23/2014         934
# 1       Offline              L  2/22/2015  874708545   2/27/2015        4551
# 2       Offline              M  12/9/2015  854349935   1/18/2016        9986
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      152.58      97.44      142509.72    91008.96      51500.76
# 1      437.20     263.33     1989697.20  1198414.83     791282.37
# 2        9.33       6.92       93169.38    69103.12      24066.26

# %% [markdown]
# **2. Pick the Right Container**

# %% [markdown]
# We'll use a custom Transaction class because:
#
# 1. It provides type safety and validation during object creation
# 2. Allows for custom methods to be added later
# 3. More readable than dictionaries with string keys
# 4. More flexible than namedtuple which is immutable

# %% [markdown]
# **3. Transaction Class and OO Data Structure**

# %%
from dataclasses import dataclass
from datetime import datetime
from typing import Optional

@dataclass
class Transaction:
    date: str
    customer_id: str
    product: str
    price: float
    quantity: int
    coupon_code: Optional[str]
    shipping_city: str
    
    def __post_init__(self):
        # Basic validation
        if self.price <= 0:
            raise ValueError("Price must be positive")
        if self.quantity <= 0:
            raise ValueError("Quantity must be positive")

# %% [markdown]
# **4. Bulk Loader**

# %%
from dataclasses import dataclass
from typing import List, Optional
import pandas as pd

@dataclass
class Transaction:
    date: str
    customer_id: str
    product: str
    price: float
    quantity: int
    coupon_code: Optional[str]
    shipping_city: str
    
    def __post_init__(self):
        """Validation logic"""
        if self.price <= 0:
            raise ValueError("Price must be positive")
        if self.quantity <= 0:
            raise ValueError("Quantity must be positive")

def load_transactions(file_path: str) -> List[Transaction]:
    """Load transactions from CSV file into list of Transaction objects"""
    try:
        df = pd.read_csv(file_path)
        print(f"Successfully loaded {len(df)} rows from CSV")
    except Exception as e:
        print(f"Failed to read CSV file: {e}")
        return []

    transactions = []
    error_count = 0
    
    for index, row in df.iterrows():
        try:
            transaction = Transaction(
                date=row['Date'],
                customer_id=str(row['Customer ID']),
                product=row['Product'],
                price=float(row['Price']),
                quantity=int(row['Quantity']),
                coupon_code=row.get('Coupon Code', None),
                shipping_city=row['Shipping City']
            )
            transactions.append(transaction)
        except Exception as e:
            error_count += 1
            print(f"Error in row {index + 1}: {str(e)}")
    
    print(f"Successfully created {len(transactions)} transactions ({error_count} errors)")
    return transactions

# Usage with your absolute path
file_path = r'D:\AI ML\Machine learning Programming\Lab 2\raw_transactions.csv'
transactions = load_transactions(file_path)

# Verify loaded data
if transactions:
    print("\nFirst transaction sample:")
    print(vars(transactions[0]))
else:
    print("\nNo transactions were loaded. Please check:")
    print("1. The file path is correct")
    print("2. The CSV file contains data")
    print("3. The column names match the expected format")
# Out:
# Successfully loaded 100000 rows from CSV
# Error in row 1: 'Date'
# Error in row 2: 'Date'
# Error in row 3: 'Date'
# Error in row 4: 'Date'
# Error in row 5: 'Date'
# Error in row 6: 'Date'
# Error in row 7: 'Date'
# Error in row 8: 'Date'
# Error in row 9: 'Date'
# Error in row 10: 'Date'
# Error in row 11: 'Date'
# Error in row 12: 'Date'
# Error in row 13: 'Date'
# Error in row 14: 'Date'
# Error in row 15: 'Date'
# Error in row 16: 'Date'
# Error in row 17: 'Date'
# Error in row 18: 'Date'
# Error in row 19: 'Date'
# Error in row 20: 'Date'
# Error in row 21: 'Date'
# Error in row 22: 'Date'
# Error in row 23: 'Date'
# Error in row 24: 'Date'
# Error in row 25: 'Date'
# Error in row 26: 'Date'
# Error in row 27: 'Date'
# Error in row 28: 'Date'
# Error in row 29: 'Date'
# Error in row 30: 'Date'
# Error in row 31: 'Date'
# Error in row 32: 'Date'
# Error in row 33: 'Date'
# Error in row 34: 'Date'
# Error in row 35: 'Date'
# Error in row 36: 'Date'
# Error in row 37: 'Date'
# Error in row 38: 'Date'
# Error in row 39: 'Date'
# Error in row 40: 'Date'
# Error in row 41: 'Date'
# Error in row 42: 'Date'
# Error in row 43: 'Date'
# Error in row 44: 'Date'
# Error in row 45: 'Date'
# Error in row 46: 'Date'
# Error in row 47: 'Date'
# Error in row 48: 'Date'
# Error in row 49: 'Date'
# Error in row 50: 'Date'
# Error in row 51: 'Date'
# Error in row 52: 'Date'
# Error in row 53: 'Date'
# Error in row 54: 'Date'
# Error in row 55: 'Date'
# Error in row 56: 'Date'
# Error in row 57: 'Date'
# Error in row 58: 'Date'
# Error in row 59: 'Date'
# Error in row 60: 'Date'
# Error in row 61: 'Date'
# Error in row 62: 'Date'
# Error in row 63: 'Date'
# Error in row 64: 'Date'
# Error in row 65: 'Date'
# Error in row 66: 'Date'
# Error in row 67: 'Date'
# Error in row 68: 'Date'
# Error in row 69: 'Date'
# Error in row 70: 'Date'
# Error in row 71: 'Date'
# Error in row 72: 'Date'
# Error in row 73: 'Date'
# Error in row 74: 'Date'
# Error in row 75: 'Date'
# Error in row 76: 'Date'
# Error in row 77: 'Date'
# Error in row 78: 'Date'
# Error in row 79: 'Date'
# Error in row 80: 'Date'
# Error in row 81: 'Date'
# Error in row 82: 'Date'
# Error in row 83: 'Date'
# Error in row 84: 'Date'
# Error in row 85: 'Date'
# Error in row 86: 'Date'
# Error in row 87: 'Date'
# Error in row 88: 'Date'
# Error in row 89: 'Date'
# Error in row 90: 'Date'
# Error in row 91: 'Date'
# Error in row 92: 'Date'
# Error in row 93: 'Date'
# Error in row 94: 'Date'
# Error in row 95: 'Date'
# Error in row 96: 'Date'
# Error in row 97: 'Date'
# Error in row 98: 'Date'
# Error in row 99: 'Date'
# Error in row 100: 'Date'
# Error in row 101: 'Date'
# Error in row 102: 'Date'
# Error in row 103: 'Date'
# Error in row 104: 'Date'
# Error in row 105: 'Date'
# Error in row 106: 'Date'
# Error in row 107: 'Date'
# Error in row 108: 'Date'
# Error in row 109: 'Date'
# Error in row 110: 'Date'
# Error in row 111: 'Date'
# Error in row 112: 'Date'
# Error in row 113: 'Date'
# Error in row 114: 'Date'
# Error in row 115: 'Date'
# Error in row 116: 'Date'
# Error in row 117: 'Date'
# Error in row 118: 'Date'
# Error in row 119: 'Date'
# Error in row 120: 'Date'
# Error in row 121: 'Date'
# Error in row 122: 'Date'
# Error in row 123: 'Date'
# Error in row 124: 'Date'
# Error in row 125: 'Date'
# Error in row 126: 'Date'
# Error in row 127: 'Date'
# Error in row 128: 'Date'
# Error in row 129: 'Date'
# Error in row 130: 'Date'
# Error in row 131: 'Date'
# Error in row 132: 'Date'
# Error in row 133: 'Date'
# Error in row 134: 'Date'
# Error in row 135: 'Date'
# Error in row 136: 'Date'
# Error in row 137: 'Date'
# Error in row 138: 'Date'
# Error in row 139: 'Date'
# Error in row 140: 'Date'
# Error in row 141: 'Date'
# Error in row 142: 'Date'
# Error in row 143: 'Date'
# Error in row 144: 'Date'
# Error in row 145: 'Date'
# Error in row 146: 'Date'
# Error in row 147: 'Date'
# Error in row 148: 'Date'
# Error in row 149: 'Date'
# Error in row 150: 'Date'
# Error in row 151: 'Date'
# Error in row 152: 'Date'
# Error in row 153: 'Date'
# Error in row 154: 'Date'
# Error in row 155: 'Date'
# Error in row 156: 'Date'
# Error in row 157: 'Date'
# Error in row 158: 'Date'
# Error in row 159: 'Date'
# Error in row 160: 'Date'
# Error in row 161: 'Date'
# Error in row 162: 'Date'
# Error in row 163: 'Date'
# Error in row 164: 'Date'
# Error in row 165: 'Date'
# Error in row 166: 'Date'
# Error in row 167: 'Date'
# Error in row 168: 'Date'
# Error in row 169: 'Date'
# Error in row 170: 'Date'
# Error in row 171: 'Date'
# Error in row 172: 'Date'
# Error in row 173: 'Date'
# Error in row 174: 'Date'
# Error in row 175: 'Date'
# Error in row 176: 'Date'
# Error in row 177: 'Date'
# Error in row 178: 'Date'
# Error in row 179: 'Date'
# Error in row 180: 'Date'
# Error in row 181: 'Date'
# Error in row 182: 'Date'
# Error in row 183: 'Date'
# Error in row 184: 'Date'
# Error in row 185: 'Date'
# Error in row 186: 'Date'
# Error in row 187: 'Date'
# Error in row 188: 'Date'
# Error in row 189: 'Date'
# Error in row 190: 'Date'
# Error in row 191: 'Date'
# Error in row 192: 'Date'
# Error in row 193: 'Date'
# Error in row 194: 'Date'
# Error in row 195: 'Date'
# Error in row 196: 'Date'
# Error in row 197: 'Date'
# Error in row 198: 'Date'
# Error in row 199: 'Date'
# Error in row 200: 'Date'
# Error in row 201: 'Date'
# Error in row 202: 'Date'
# Error in row 203: 'Date'
# Error in row 204: 'Date'
# Error in row 205: 'Date'
# Error in row 206: 'Date'
# Error in row 207: 'Date'
# Error in row 208: 'Date'
# Error in row 209: 'Date'
# Error in row 210: 'Date'
# Error in row 211: 'Date'
# Error in row 212: 'Date'
# Error in row 213: 'Date'
# Error in row 214: 'Date'
# Error in row 215: 'Date'
# Error in row 216: 'Date'
# Error in row 217: 'Date'
# Error in row 218: 'Date'
# Error in row 219: 'Date'
# Error in row 220: 'Date'
# Error in row 221: 'Date'
# Error in row 222: 'Date'
# Error in row 223: 'Date'
# Error in row 224: 'Date'
# Error in row 225: 'Date'
# Error in row 226: 'Date'
# Error in row 227: 'Date'
# Error in row 228: 'Date'
# Error in row 229: 'Date'
# Error in row 230: 'Date'
# Error in row 231: 'Date'
# Error in row 232: 'Date'
# Error in row 233: 'Date'
# Error in row 234: 'Date'
# Error in row 235: 'Date'
# Error in row 236: 'Date'
# Error in row 237: 'Date'
# Error in row 238: 'Date'
# Error in row 239: 'Date'
# Error in row 240: 'Date'
# Error in row 241: 'Date'
# Error in row 242: 'Date'
# Error in row 243: 'Date'
# Error in row 244: 'Date'
# Error in row 245: 'Date'
# Error in row 246: 'Date'
# Error in row 247: 'Date'
# Error in row 248: 'Date'
# Error in row 249: 'Date'
# Error in row 250: 'Date'
# Error in row 251: 'Date'
# Error in row 252: 'Date'
# Error in row 253: 'Date'
# Error in row 254: 'Date'
# Error in row 255: 'Date'
# Error in row 256: 'Date'
# Error in row 257: 'Date'
# Error in row 258: 'Date'
# Error in row 259: 'Date'
# Error in row 260: 'Date'
# Error in row 261: 'Date'
# Error in row 262: 'Date'
# Error in row 263: 'Date'
# Error in row 264: 'Date'
# Error in row 265: 'Date'
# Error in row 266: 'Date'
# Error in row 267: 'Date'
# Error in row 268: 'Date'
# Error in row 269: 'Date'
# Error in row 270: 'Date'
# Error in row 271: 'Date'
# Error in row 272: 'Date'
# Error in row 273: 'Date'
# Error in row 274: 'Date'
# Error in row 275: 'Date'
# Error in row 276: 'Date'
# Error in row 277: 'Date'
# Error in row 278: 'Date'
# Error in row 279: 'Date'
# Error in row 280: 'Date'
# Error in row 281: 'Date'
# Error in row 282: 'Date'
# Error in row 283: 'Date'
# Error in row 284: 'Date'
# Error in row 285: 'Date'
# Error in row 286: 'Date'
# Error in row 287: 'Date'
# Error in row 288: 'Date'
# Error in row 289: 'Date'
# Error in row 290: 'Date'
# Error in row 291: 'Date'
# Error in row 292: 'Date'
# Error in row 293: 'Date'
# Error in row 294: 'Date'
# Error in row 295: 'Date'
# Error in row 296: 'Date'
# Error in row 297: 'Date'
# Error in row 298: 'Date'
# Error in row 299: 'Date'
# Error in row 300: 'Date'
# Error in row 301: 'Date'
# Error in row 302: 'Date'
# Error in row 303: 'Date'
# Error in row 304: 'Date'
# Error in row 305: 'Date'
# Error in row 306: 'Date'
# Error in row 307: 'Date'
# Error in row 308: 'Date'
# Error in row 309: 'Date'
# Error in row 310: 'Date'
# Error in row 311: 'Date'
# Error in row 312: 'Date'
# Error in row 313: 'Date'
# Error in row 314: 'Date'
# Error in row 315: 'Date'
# Error in row 316: 'Date'
# Error in row 317: 'Date'
# Error in row 318: 'Date'
# Error in row 319: 'Date'
# Error in row 320: 'Date'
# Error in row 321: 'Date'
# Error in row 322: 'Date'
# Error in row 323: 'Date'
# Error in row 324: 'Date'
# Error in row 325: 'Date'
# Error in row 326: 'Date'
# Error in row 327: 'Date'
# Error in row 328: 'Date'
# Error in row 329: 'Date'
# Error in row 330: 'Date'
# Error in row 331: 'Date'
# Error in row 332: 'Date'
# Error in row 333: 'Date'
# Error in row 334: 'Date'
# Error in row 335: 'Date'
# Error in row 336: 'Date'
# Error in row 337: 'Date'
# Error in row 338: 'Date'
# Error in row 339: 'Date'
# Error in row 340: 'Date'
# Error in row 341: 'Date'
# Error in row 342: 'Date'
# Error in row 343: 'Date'
# Error in row 344: 'Date'
# Error in row 345: 'Date'
# Error in row 346: 'Date'
# Error in row 347: 'Date'
# Error in row 348: 'Date'
# Error in row 349: 'Date'
# Error in row 350: 'Date'
# Error in row 351: 'Date'
# Error in row 352: 'Date'
# Error in row 353: 'Date'
# Error in row 354: 'Date'
# Error in row 355: 'Date'
# Error in row 356: 'Date'
# Error in row 357: 'Date'
# Error in row 358: 'Date'
# Error in row 359: 'Date'
# Error in row 360: 'Date'
# Error in row 361: 'Date'
# Error in row 362: 'Date'
# Error in row 363: 'Date'
# Error in row 364: 'Date'
# Error in row 365: 'Date'
# Error in row 366: 'Date'
# Error in row 367: 'Date'
# Error in row 368: 'Date'
# Error in row 369: 'Date'
# Error in row 370: 'Date'
# Error in row 371: 'Date'
# Error in row 372: 'Date'
# Error in row 373: 'Date'
# Error in row 374: 'Date'
# Error in row 375: 'Date'
# Error in row 376: 'Date'
# Error in row 377: 'Date'
# Error in row 378: 'Date'
# Error in row 379: 'Date'
# Error in row 380: 'Date'
# Error in row 381: 'Date'
# Error in row 382: 'Date'
# Error in row 383: 'Date'
# Error in row 384: 'Date'
# Error in row 385: 'Date'
# Error in row 386: 'Date'
# Error in row 387: 'Date'
# Error in row 388: 'Date'
# Error in row 389: 'Date'
# Error in row 390: 'Date'
# Error in row 391: 'Date'
# Error in row 392: 'Date'
# Error in row 393: 'Date'
# Error in row 394: 'Date'
# Error in row 395: 'Date'
# Error in row 396: 'Date'
# Error in row 397: 'Date'
# Error in row 398: 'Date'
# Error in row 399: 'Date'
# Error in row 400: 'Date'
# Error in row 401: 'Date'
# Error in row 402: 'Date'
# Error in row 403: 'Date'
# Error in row 404: 'Date'
# Error in row 405: 'Date'
# Error in row 406: 'Date'
# Error in row 407: 'Date'
# Error in row 408: 'Date'
# Error in row 409: 'Date'
# Error in row 410: 'Date'
# Error in row 411: 'Date'
# Error in row 412: 'Date'
# Error in row 413: 'Date'
# Error in row 414: 'Date'
# Error in row 415: 'Date'
# Error in row 416: 'Date'
# Error in row 417: 'Date'
# Error in row 418: 'Date'
# Error in row 419: 'Date'
# Error in row 420: 'Date'
# Error in row 421: 'Date'
# Error in row 422: 'Date'
# Error in row 423: 'Date'
# Error in row 424: 'Date'
# Error in row 425: 'Date'
# Error in row 426: 'Date'
# Error in row 427: 'Date'
# Error in row 428: 'Date'
# Error in row 429: 'Date'
# Error in row 430: 'Date'
# Error in row 431: 'Date'
# Error in row 432: 'Date'
# Error in row 433: 'Date'
# Error in row 434: 'Date'
# Error in row 435: 'Date'
# Error in row 436: 'Date'
# Error in row 437: 'Date'
# Error in row 438: 'Date'
# Error in row 439: 'Date'
# Error in row 440: 'Date'
# Error in row 441: 'Date'
# Error in row 442: 'Date'
# Error in row 443: 'Date'
# Error in row 444: 'Date'
# Error in row 445: 'Date'
# Error in row 446: 'Date'
# Error in row 447: 'Date'
# Error in row 448: 'Date'
# Error in row 449: 'Date'
# Error in row 450: 'Date'
# Error in row 451: 'Date'
# Error in row 452: 'Date'
# Error in row 453: 'Date'
# Error in row 454: 'Date'
# Error in row 455: 'Date'
# Error in row 456: 'Date'
# Error in row 457: 'Date'
# Error in row 458: 'Date'
# Error in row 459: 'Date'
# Error in row 460: 'Date'
# Error in row 461: 'Date'
# Error in row 462: 'Date'
# Error in row 463: 'Date'
# Error in row 464: 'Date'
# Error in row 465: 'Date'
# Error in row 466: 'Date'
# Error in row 467: 'Date'
# Error in row 468: 'Date'
# Error in row 469: 'Date'
# Error in row 470: 'Date'
# Error in row 471: 'Date'
# Error in row 472: 'Date'
# Error in row 473: 'Date'
# Error in row 474: 'Date'
# Error in row 475: 'Date'
# Error in row 476: 'Date'
# Error in row 477: 'Date'
# Error in row 478: 'Date'
# Error in row 479: 'Date'
# Error in row 480: 'Date'
# Error in row 481: 'Date'
# Error in row 482: 'Date'
# Error in row 483: 'Date'
# Error in row 484: 'Date'
# Error in row 485: 'Date'
# Error in row 486: 'Date'
# Error in row 487: 'Date'
# Error in row 488: 'Date'
# Error in row 489: 'Date'
# Error in row 490: 'Date'
# Error in row 491: 'Date'
# Error in row 492: 'Date'
# Error in row 493: 'Date'
# Error in row 494: 'Date'
# Error in row 495: 'Date'
# Error in row 496: 'Date'
# Error in row 497: 'Date'
# Error in row 498: 'Date'
# Error in row 499: 'Date'
# Error in row 500: 'Date'
# Error in row 501: 'Date'
# Error in row 502: 'Date'
# Error in row 503: 'Date'
# Error in row 504: 'Date'
# Error in row 505: 'Date'
# Error in row 506: 'Date'
# Error in row 507: 'Date'
# Error in row 508: 'Date'
# Error in row 509: 'Date'
# Error in row 510: 'Date'
# Error in row 511: 'Date'
# Error in row 512: 'Date'
# Error in row 513: 'Date'
# Error in row 514: 'Date'
# Error in row 515: 'Date'
# Error in row 516: 'Date'
# Error in row 517: 'Date'
# Error in row 518: 'Date'
# Error in row 519: 'Date'
# Error in row 520: 'Date'
# Error in row 521: 'Date'
# Error in row 522: 'Date'
# Error in row 523: 'Date'
# Error in row 524: 'Date'
# Error in row 525: 'Date'
# Error in row 526: 'Date'
# Error in row 527: 'Date'
# Error in row 528: 'Date'
# Error in row 529: 'Date'
# Error in row 530: 'Date'
# Error in row 531: 'Date'
# Error in row 532: 'Date'
# Error in row 533: 'Date'
# Error in row 534: 'Date'
# Error in row 535: 'Date'
# Error in row 536: 'Date'
# Error in row 537: 'Date'
# Error in row 538: 'Date'
# Error in row 539: 'Date'
# Error in row 540: 'Date'
# Error in row 541: 'Date'
# Error in row 542: 'Date'
# Error in row 543: 'Date'
# Error in row 544: 'Date'
# Error in row 545: 'Date'
# Error in row 546: 'Date'
# Error in row 547: 'Date'
# Error in row 548: 'Date'
# Error in row 549: 'Date'
# Error in row 550: 'Date'
# Error in row 551: 'Date'
# Error in row 552: 'Date'
# Error in row 553: 'Date'
# Error in row 554: 'Date'
# Error in row 555: 'Date'
# Error in row 556: 'Date'
# Error in row 557: 'Date'
# Error in row 558: 'Date'
# Error in row 559: 'Date'
# Error in row 560: 'Date'
# Error in row 561: 'Date'
# Error in row 562: 'Date'
# Error in row 563: 'Date'
# Error in row 564: 'Date'
# Error in row 565: 'Date'
# Error in row 566: 'Date'
# Error in row 567: 'Date'
# Error in row 568: 'Date'
# Error in row 569: 'Date'
# Error in row 570: 'Date'
# Error in row 571: 'Date'
# Error in row 572: 'Date'
# Error in row 573: 'Date'
# Error in row 574: 'Date'
# Error in row 575: 'Date'
# Error in row 576: 'Date'
# Error in row 577: 'Date'
# Error in row 578: 'Date'
# Error in row 579: 'Date'
# Error in row 580: 'Date'
# Error in row 581: 'Date'
# Error in row 582: 'Date'
# Error in row 583: 'Date'
# Error in row 584: 'Date'
# Error in row 585: 'Date'
# Error in row 586: 'Date'
# Error in row 587: 'Date'
# Error in row 588: 'Date'
# Error in row 589: 'Date'
# Error in row 590: 'Date'
# Error in row 591: 'Date'
# Error in row 592: 'Date'
# Error in row 593: 'Date'
# Error in row 594: 'Date'
# Error in row 595: 'Date'
# Error in row 596: 'Date'
# Error in row 597: 'Date'
# Error in row 598: 'Date'
# Error in row 599: 'Date'
# Error in row 600: 'Date'
# Error in row 601: 'Date'
# Error in row 602: 'Date'
# Error in row 603: 'Date'
# Error in row 604: 'Date'
# Error in row 605: 'Date'
# Error in row 606: 'Date'
# Error in row 607: 'Date'
# Error in row 608: 'Date'
# Error in row 609: 'Date'
# Error in row 610: 'Date'
# Error in row 611: 'Date'
# Error in row 612: 'Date'
# Error in row 613: 'Date'
# Error in row 614: 'Date'
# Error in row 615: 'Date'
# Error in row 616: 'Date'
# Error in row 617: 'Date'
# Error in row 618: 'Date'
# Error in row 619: 'Date'
# Error in row 620: 'Date'
# Error in row 621: 'Date'
# Error in row 622: 'Date'
# Error in row 623: 'Date'
# Error in row 624: 'Date'
# Error in row 625: 'Date'
# Error in row 626: 'Date'
# Error in row 627: 'Date'
# Error in row 628: 'Date'
# Error in row 629: 'Date'
# Error in row 630: 'Date'
# Error in row 631: 'Date'
# Error in row 632: 'Date'
# Error in row 633: 'Date'
# Error in row 634: 'Date'
# Error in row 635: 'Date'
# Error in row 636: 'Date'
# Error in row 637: 'Date'
# Error in row 638: 'Date'
# Error in row 639: 'Date'
# Error in row 640: 'Date'
# Error in row 641: 'Date'
# Error in row 642: 'Date'
# Error in row 643: 'Date'
# Error in row 644: 'Date'
# Error in row 645: 'Date'
# Error in row 646: 'Date'
# Error in row 647: 'Date'
# Error in row 648: 'Date'
# Error in row 649: 'Date'
# Error in row 650: 'Date'
# Error in row 651: 'Date'
# Error in row 652: 'Date'
# Error in row 653: 'Date'
# Error in row 654: 'Date'
# Error in row 655: 'Date'
# Error in row 656: 'Date'
# Error in row 657: 'Date'
# Error in row 658: 'Date'
# Error in row 659: 'Date'
# Error in row 660: 'Date'
# Error in row 661: 'Date'
# Error in row 662: 'Date'
# Error in row 663: 'Date'
# Error in row 664: 'Date'
# Error in row 665: 'Date'
# Error in row 666: 'Date'
# Error in row 667: 'Date'
# Error in row 668: 'Date'
# Error in row 669: 'Date'
# Error in row 670: 'Date'
# Error in row 671: 'Date'
# Error in row 672: 'Date'
# Error in row 673: 'Date'
# Error in row 674: 'Date'
# Error in row 675: 'Date'
# Error in row 676: 'Date'
# Error in row 677: 'Date'
# Error in row 678: 'Date'
# Error in row 679: 'Date'
# Error in row 680: 'Date'
# Error in row 681: 'Date'
# Error in row 682: 'Date'
# Error in row 683: 'Date'
# Error in row 684: 'Date'
# Error in row 685: 'Date'
# Error in row 686: 'Date'
# Error in row 687: 'Date'
# Error in row 688: 'Date'
# Error in row 689: 'Date'
# Error in row 690: 'Date'
# Error in row 691: 'Date'
# Error in row 692: 'Date'
# Error in row 693: 'Date'
# Error in row 694: 'Date'
# Error in row 695: 'Date'
# Error in row 696: 'Date'
# Error in row 697: 'Date'
# Error in row 698: 'Date'
# Error in row 699: 'Date'
# Error in row 700: 'Date'
# Error in row 701: 'Date'
# Error in row 702: 'Date'
# Error in row 703: 'Date'
# Error in row 704: 'Date'
# Error in row 705: 'Date'
# Error in row 706: 'Date'
# Error in row 707: 'Date'
# Error in row 708: 'Date'
# Error in row 709: 'Date'
# Error in row 710: 'Date'
# Error in row 711: 'Date'
# Error in row 712: 'Date'
# Error in row 713: 'Date'
# Error in row 714: 'Date'
# Error in row 715: 'Date'
# Error in row 716: 'Date'
# Error in row 717: 'Date'
# Error in row 718: 'Date'
# Error in row 719: 'Date'
# Error in row 720: 'Date'
# Error in row 721: 'Date'
# Error in row 722: 'Date'
# Error in row 723: 'Date'
# Error in row 724: 'Date'
# Error in row 725: 'Date'
# Error in row 726: 'Date'
# Error in row 727: 'Date'
# Error in row 728: 'Date'
# Error in row 729: 'Date'
# Error in row 730: 'Date'
# Error in row 731: 'Date'
# Error in row 732: 'Date'
# Error in row 733: 'Date'
# Error in row 734: 'Date'
# Error in row 735: 'Date'
# Error in row 736: 'Date'
# Error in row 737: 'Date'
# Error in row 738: 'Date'
# Error in row 739: 'Date'
# Error in row 740: 'Date'
# Error in row 741: 'Date'
# Error in row 742: 'Date'
# Error in row 743: 'Date'
# Error in row 744: 'Date'
# Error in row 745: 'Date'
# Error in row 746: 'Date'
# Error in row 747: 'Date'
# Error in row 748: 'Date'
# Error in row 749: 'Date'
# Error in row 750: 'Date'
# Error in row 751: 'Date'
# Error in row 752: 'Date'
# Error in row 753: 'Date'
# Error in row 754: 'Date'
# Error in row 755: 'Date'
# Error in row 756: 'Date'
# Error in row 757: 'Date'
# Error in row 758: 'Date'
# Error in row 759: 'Date'
# Error in row 760: 'Date'
# Error in row 761: 'Date'
# Error in row 762: 'Date'
# Error in row 763: 'Date'
# Error in row 764: 'Date'
# Error in row 765: 'Date'
# Error in row 766: 'Date'
# Error in row 767: 'Date'
# Error in row 768: 'Date'
# Error in row 769: 'Date'
# Error in row 770: 'Date'
# Error in row 771: 'Date'
# Error in row 772: 'Date'
# Error in row 773: 'Date'
# Error in row 774: 'Date'
# Error in row 775: 'Date'
# Error in row 776: 'Date'
# Error in row 777: 'Date'
# Error in row 778: 'Date'
# Error in row 779: 'Date'
# Error in row 780: 'Date'
# Error in row 781: 'Date'
# Error in row 782: 'Date'
# Error in row 783: 'Date'
# Error in row 784: 'Date'
# Error in row 785: 'Date'
# Error in row 786: 'Date'
# Error in row 787: 'Date'
# Error in row 788: 'Date'
# Error in row 789: 'Date'
# Error in row 790: 'Date'
# Error in row 791: 'Date'
# Error in row 792: 'Date'
# Error in row 793: 'Date'
# Error in row 794: 'Date'
# Error in row 795: 'Date'
# Error in row 796: 'Date'
# Error in row 797: 'Date'
# Error in row 798: 'Date'
# Error in row 799: 'Date'
# Error in row 800: 'Date'
# Error in row 801: 'Date'
# Error in row 802: 'Date'
# Error in row 803: 'Date'
# Error in row 804: 'Date'
# Error in row 805: 'Date'
# Error in row 806: 'Date'
# Error in row 807: 'Date'
# Error in row 808: 'Date'
# Error in row 809: 'Date'
# Error in row 810: 'Date'
# Error in row 811: 'Date'
# Error in row 812: 'Date'
# Error in row 813: 'Date'
# Error in row 814: 'Date'
# Error in row 815: 'Date'
# Error in row 816: 'Date'
# Error in row 817: 'Date'
# Error in row 818: 'Date'
# Error in row 819: 'Date'
# Error in row 820: 'Date'
# Error in row 821: 'Date'
# Error in row 822: 'Date'
# Error in row 823: 'Date'
# Error in row 824: 'Date'
# Error in row 825: 'Date'
# Error in row 826: 'Date'
# Error in row 827: 'Date'
# Error in row 828: 'Date'
# Error in row 829: 'Date'
# Error in row 830: 'Date'
# Error in row 831: 'Date'
# Error in row 832: 'Date'
# Error in row 833: 'Date'
# Error in row 834: 'Date'
# Error in row 835: 'Date'
# Error in row 836: 'Date'
# Error in row 837: 'Date'
# Error in row 838: 'Date'
# Error in row 839: 'Date'
# Error in row 840: 'Date'
# Error in row 841: 'Date'
# Error in row 842: 'Date'
# Error in row 843: 'Date'
# Error in row 844: 'Date'
# Error in row 845: 'Date'
# Error in row 846: 'Date'
# Error in row 847: 'Date'
# Error in row 848: 'Date'
# Error in row 849: 'Date'
# Error in row 850: 'Date'
# Error in row 851: 'Date'
# Error in row 852: 'Date'
# Error in row 853: 'Date'
# Error in row 854: 'Date'
# Error in row 855: 'Date'
# Error in row 856: 'Date'
# Error in row 857: 'Date'
# Error in row 858: 'Date'
# Error in row 859: 'Date'
# Error in row 860: 'Date'
# Error in row 861: 'Date'
# Error in row 862: 'Date'
# Error in row 863: 'Date'
# Error in row 864: 'Date'
# Error in row 865: 'Date'
# Error in row 866: 'Date'
# Error in row 867: 'Date'
# Error in row 868: 'Date'
# Error in row 869: 'Date'
# Error in row 870: 'Date'
# Error in row 871: 'Date'
# Error in row 872: 'Date'
# Error in row 873: 'Date'
# Error in row 874: 'Date'
# Error in row 875: 'Date'
# Error in row 876: 'Date'
# Error in row 877: 'Date'
# Error in row 878: 'Date'
# Error in row 879: 'Date'
# Error in row 880: 'Date'
# Error in row 881: 'Date'
# Error in row 882: 'Date'
# Error in row 883: 'Date'
# Error in row 884: 'Date'
# Error in row 885: 'Date'
# Error in row 886: 'Date'
# Error in row 887: 'Date'
# Error in row 888: 'Date'
# Error in row 889: 'Date'
# Error in row 890: 'Date'
# Error in row 891: 'Date'
# Error in row 892: 'Date'
# Error in row 893: 'Date'
# Error in row 894: 'Date'
# Error in row 895: 'Date'
# Error in row 896: 'Date'
# Error in row 897: 'Date'
# Error in row 898: 'Date'
# Error in row 899: 'Date'
# Error in row 900: 'Date'
# Error in row 901: 'Date'
# Error in row 902: 'Date'
# Error in row 903: 'Date'
# Error in row 904: 'Date'
# Error in row 905: 'Date'
# Error in row 906: 'Date'
# Error in row 907: 'Date'
# Error in row 908: 'Date'
# Error in row 909: 'Date'
# Error in row 910: 'Date'
# Error in row 911: 'Date'
# Error in row 912: 'Date'
# Error in row 913: 'Date'
# Error in row 914: 'Date'
# Error in row 915: 'Date'
# Error in row 916: 'Date'
# Error in row 917: 'Date'
# Error in row 918: 'Date'
# Error in row 919: 'Date'
# Error in row 920: 'Date'
# Error in row 921: 'Date'
# Error in row 922: 'Date'
# Error in row 923: 'Date'
# Error in row 924: 'Date'
# Error in row 925: 'Date'
# Error in row 926: 'Date'
# Error in row 927: 'Date'
# Error in row 928: 'Date'
# Error in row 929: 'Date'
# Error in row 930: 'Date'
# Error in row 931: 'Date'
# Error in row 932: 'Date'
# Error in row 933: 'Date'
# Error in row 934: 'Date'
# Error in row 935: 'Date'
# Error in row 936: 'Date'
# Error in row 937: 'Date'
# Error in row 938: 'Date'
# Error in row 939: 'Date'
# Error in row 940: 'Date'
# Error in row 941: 'Date'
# Error in row 942: 'Date'
# Error in row 943: 'Date'
# Error in row 944: 'Date'
# Error in row 945: 'Date'
# Error in row 946: 'Date'
# Error in row 947: 'Date'
# Error in row 948: 'Date'
# Error in row 949: 'Date'
# Error in row 950: 'Date'
# Error in row 951: 'Date'
# Error in row 952: 'Date'
# Error in row 953: 'Date'
# Error in row 954: 'Date'
# Error in row 955: 'Date'
# Error in row 956: 'Date'
# Error in row 957: 'Date'
# Error in row 958: 'Date'
# Error in row 959: 'Date'
# Error in row 960: 'Date'
# Error in row 961: 'Date'
# Error in row 962: 'Date'
# Error in row 963: 'Date'
# Error in row 964: 'Date'
# Error in row 965: 'Date'
# Error in row 966: 'Date'
# Error in row 967: 'Date'
# Error in row 968: 'Date'
# Error in row 969: 'Date'
# Error in row 970: 'Date'
# Error in row 971: 'Date'
# Error in row 972: 'Date'
# Error in row 973: 'Date'
# Error in row 974: 'Date'
# Error in row 975: 'Date'
# Error in row 976: 'Date'
# Error in row 977: 'Date'
# Error in row 978: 'Date'
# Error in row 979: 'Date'
# Error in row 980: 'Date'
# Error in row 981: 'Date'
# Error in row 982: 'Date'
# Error in row 983: 'Date'
# Error in row 984: 'Date'
# Error in row 985: 'Date'
# Error in row 986: 'Date'
# Error in row 987: 'Date'
# Error in row 988: 'Date'
# Error in row 989: 'Date'
# Error in row 990: 'Date'
# Error in row 991: 'Date'
# Error in row 992: 'Date'
# Error in row 993: 'Date'
# Error in row 994: 'Date'
# Error in row 995: 'Date'
# Error in row 996: 'Date'
# Error in row 997: 'Date'
# Error in row 998: 'Date'
# Error in row 999: 'Date'
# Error in row 1000: 'Date'
# Error in row 1001: 'Date'
# Error in row 1002: 'Date'
# Error in row 1003: 'Date'
# Error in row 1004: 'Date'
# Error in row 1005: 'Date'
# Error in row 1006: 'Date'
# Error in row 1007: 'Date'
# Error in row 1008: 'Date'
# Error in row 1009: 'Date'
# Error in row 1010: 'Date'
# Error in row 1011: 'Date'
# Error in row 1012: 'Date'
# Error in row 1013: 'Date'
# Error in row 1014: 'Date'
# Error in row 1015: 'Date'
# Error in row 1016: 'Date'
# Error in row 1017: 'Date'
# Error in row 1018: 'Date'
# Error in row 1019: 'Date'
# Error in row 1020: 'Date'
# Error in row 1021: 'Date'
# Error in row 1022: 'Date'
# Error in row 1023: 'Date'
# Error in row 1024: 'Date'
# Error in row 1025: 'Date'
# Error in row 1026: 'Date'
# Error in row 1027: 'Date'
# Error in row 1028: 'Date'
# Error in row 1029: 'Date'
# Error in row 1030: 'Date'
# Error in row 1031: 'Date'
# Error in row 1032: 'Date'
# Error in row 1033: 'Date'
# Error in row 1034: 'Date'
# Error in row 1035: 'Date'
# Error in row 1036: 'Date'
# Error in row 1037: 'Date'
# Error in row 1038: 'Date'
# Error in row 1039: 'Date'
# Error in row 1040: 'Date'
# Error in row 1041: 'Date'
# Error in row 1042: 'Date'
# Error in row 1043: 'Date'
# Error in row 1044: 'Date'
# Error in row 1045: 'Date'
# Error in row 1046: 'Date'
# Error in row 1047: 'Date'
# Error in row 1048: 'Date'
# Error in row 1049: 'Date'
# Error in row 1050: 'Date'
# Error in row 1051: 'Date'
# Error in row 1052: 'Date'
# Error in row 1053: 'Date'
# Error in row 1054: 'Date'
# Error in row 1055: 'Date'
# Error in row 1056: 'Date'
# Error in row 1057: 'Date'
# Error in row 1058: 'Date'
# Error in row 1059: 'Date'
# Error in row 1060: 'Date'
# Error in row 1061: 'Date'
# Error in row 1062: 'Date'
# Error in row 1063: 'Date'
# Error in row 1064: 'Date'
# Error in row 1065: 'Date'
# Error in row 1066: 'Date'
# Error in row 1067: 'Date'
# Error in row 1068: 'Date'
# Error in row 1069: 'Date'
# Error in row 1070: 'Date'
# Error in row 1071: 'Date'
# Error in row 1072: 'Date'
# Error in row 1073: 'Date'
# Error in row 1074: 'Date'
# Error in row 1075: 'Date'
# Error in row 1076: 'Date'
# Error in row 1077: 'Date'
# Error in row 1078: 'Date'
# Error in row 1079: 'Date'
# Error in row 1080: 'Date'
# Error in row 1081: 'Date'
# Error in row 1082: 'Date'
# Error in row 1083: 'Date'
# Error in row 1084: 'Date'
# Error in row 1085: 'Date'
# Error in row 1086: 'Date'
# Error in row 1087: 'Date'
# Error in row 1088: 'Date'
# Error in row 1089: 'Date'
# Error in row 1090: 'Date'
# Error in row 1091: 'Date'
# Error in row 1092: 'Date'
# Error in row 1093: 'Date'
# Error in row 1094: 'Date'
# Error in row 1095: 'Date'
# Error in row 1096: 'Date'
# Error in row 1097: 'Date'
# Error in row 1098: 'Date'
# Error in row 1099: 'Date'
# Error in row 1100: 'Date'
# Error in row 1101: 'Date'
# Error in row 1102: 'Date'
# Error in row 1103: 'Date'
# Error in row 1104: 'Date'
# Error in row 1105: 'Date'
# Error in row 1106: 'Date'
# Error in row 1107: 'Date'
# Error in row 1108: 'Date'
# Error in row 1109: 'Date'
# Error in row 1110: 'Date'
# Error in row 1111: 'Date'
# Error in row 1112: 'Date'
# Error in row 1113: 'Date'
# Error in row 1114: 'Date'
# Error in row 1115: 'Date'
# Error in row 1116: 'Date'
# Error in row 1117: 'Date'
# Error in row 1118: 'Date'
# Error in row 1119: 'Date'
# Error in row 1120: 'Date'
# Error in row 1121: 'Date'
# Error in row 1122: 'Date'
# Error in row 1123: 'Date'
# Error in row 1124: 'Date'
# Error in row 1125: 'Date'
# Error in row 1126: 'Date'
# Error in row 1127: 'Date'
# Error in row 1128: 'Date'
# Error in row 1129: 'Date'
# Error in row 1130: 'Date'
# Error in row 1131: 'Date'
# Error in row 1132: 'Date'
# Error in row 1133: 'Date'
# Error in row 1134: 'Date'
# Error in row 1135: 'Date'
# Error in row 1136: 'Date'
# Error in row 1137: 'Date'
# Error in row 1138: 'Date'
# Error in row 1139: 'Date'
# Error in row 1140: 'Date'
# Error in row 1141: 'Date'
# Error in row 1142: 'Date'
# Error in row 1143: 'Date'
# Error in row 1144: 'Date'
# Error in row 1145: 'Date'
# Error in row 1146: 'Date'
# Error in row 1147: 'Date'
# Error in row 1148: 'Date'
# Error in row 1149: 'Date'
# Error in row 1150: 'Date'
# Error in row 1151: 'Date'
# Error in row 1152: 'Date'
# Error in row 1153: 'Date'
# Error in row 1154: 'Date'
# Error in row 1155: 'Date'
# Error in row 1156: 'Date'
# Error in row 1157: 'Date'
# Error in row 1158: 'Date'
# Error in row 1159: 'Date'
# Error in row 1160: 'Date'
# Error in row 1161: 'Date'
# Error in row 1162: 'Date'
# Error in row 1163: 'Date'
# Error in row 1164: 'Date'
# Error in row 1165: 'Date'
# Error in row 1166: 'Date'
# Error in row 1167: 'Date'
# Error in row 1168: 'Date'
# Error in row 1169: 'Date'
# Error in row 1170: 'Date'
# Error in row 1171: 'Date'
# Error in row 1172: 'Date'
# Error in row 1173: 'Date'
# Error in row 1174: 'Date'
# Error in row 1175: 'Date'
# Error in row 1176: 'Date'
# Error in row 1177: 'Date'
# Error in row 1178: 'Date'
# Error in row 1179: 'Date'
# Error in row 1180: 'Date'
# Error in row 1181: 'Date'
# Error in row 1182: 'Date'
# Error in row 1183: 'Date'
# Error in row 1184: 'Date'
# Error in row 1185: 'Date'
# Error in row 1186: 'Date'
# Error in row 1187: 'Date'
# Error in row 1188: 'Date'
# Error in row 1189: 'Date'
# Error in row 1190: 'Date'
# Error in row 1191: 'Date'
# Error in row 1192: 'Date'
# Error in row 1193: 'Date'
# Error in row 1194: 'Date'
# Error in row 1195: 'Date'
# Error in row 1196: 'Date'
# Error in row 1197: 'Date'
# Error in row 1198: 'Date'
# Error in row 1199: 'Date'
# Error in row 1200: 'Date'
# Error in row 1201: 'Date'
# Error in row 1202: 'Date'
# Error in row 1203: 'Date'
# Error in row 1204: 'Date'
# Error in row 1205: 'Date'
# Error in row 1206: 'Date'
# Error in row 1207: 'Date'
# Error in row 1208: 'Date'
# Error in row 1209: 'Date'
# Error in row 1210: 'Date'
# Error in row 1211: 'Date'
# Error in row 1212: 'Date'
# Error in row 1213: 'Date'
# Error in row 1214: 'Date'
# Error in row 1215: 'Date'
# Error in row 1216: 'Date'
# Error in row 1217: 'Date'
# Error in row 1218: 'Date'
# Error in row 1219: 'Date'
# Error in row 1220: 'Date'
# Error in row 1221: 'Date'
# Error in row 1222: 'Date'
# Error in row 1223: 'Date'
# Error in row 1224: 'Date'
# Error in row 1225: 'Date'
# Error in row 1226: 'Date'
# Error in row 1227: 'Date'
# Error in row 1228: 'Date'
# Error in row 1229: 'Date'
# Error in row 1230: 'Date'
# Error in row 1231: 'Date'
# Error in row 1232: 'Date'
# Error in row 1233: 'Date'
# Error in row 1234: 'Date'
# Error in row 1235: 'Date'
# Error in row 1236: 'Date'
# Error in row 1237: 'Date'
# Error in row 1238: 'Date'
# Error in row 1239: 'Date'
# Error in row 1240: 'Date'
# Error in row 1241: 'Date'
# Error in row 1242: 'Date'
# Error in row 1243: 'Date'
# Error in row 1244: 'Date'
# Error in row 1245: 'Date'
# Error in row 1246: 'Date'
# Error in row 1247: 'Date'
# Error in row 1248: 'Date'
# Error in row 1249: 'Date'
# Error in row 1250: 'Date'
# Error in row 1251: 'Date'
# Error in row 1252: 'Date'
# Error in row 1253: 'Date'
# Error in row 1254: 'Date'
# Error in row 1255: 'Date'
# Error in row 1256: 'Date'
# Error in row 1257: 'Date'
# Error in row 1258: 'Date'
# Error in row 1259: 'Date'
# Error in row 1260: 'Date'
# Error in row 1261: 'Date'
# Error in row 1262: 'Date'
# Error in row 1263: 'Date'
# Error in row 1264: 'Date'
# Error in row 1265: 'Date'
# Error in row 1266: 'Date'
# Error in row 1267: 'Date'
# Error in row 1268: 'Date'
# Error in row 1269: 'Date'
# Error in row 1270: 'Date'
# Error in row 1271: 'Date'
# Error in row 1272: 'Date'
# Error in row 1273: 'Date'
# Error in row 1274: 'Date'
# Error in row 1275: 'Date'
# Error in row 1276: 'Date'
# Error in row 1277: 'Date'
# Error in row 1278: 'Date'
# Error in row 1279: 'Date'
# Error in row 1280: 'Date'
# Error in row 1281: 'Date'
# Error in row 1282: 'Date'
# Error in row 1283: 'Date'
# Error in row 1284: 'Date'
# Error in row 1285: 'Date'
# Error in row 1286: 'Date'
# Error in row 1287: 'Date'
# Error in row 1288: 'Date'
# Error in row 1289: 'Date'
# Error in row 1290: 'Date'
# Error in row 1291: 'Date'
# Error in row 1292: 'Date'
# Error in row 1293: 'Date'
# Error in row 1294: 'Date'
# Error in row 1295: 'Date'
# Error in row 1296: 'Date'
# Error in row 1297: 'Date'
# Error in row 1298: 'Date'
# Error in row 1299: 'Date'
# Error in row 1300: 'Date'
# Error in row 1301: 'Date'
# Error in row 1302: 'Date'
# Error in row 1303: 'Date'
# Error in row 1304: 'Date'
# Error in row 1305: 'Date'
# Error in row 1306: 'Date'
# Error in row 1307: 'Date'
# Error in row 1308: 'Date'
# Error in row 1309: 'Date'
# Error in row 1310: 'Date'
# Error in row 1311: 'Date'
# Error in row 1312: 'Date'
# Error in row 1313: 'Date'
# Error in row 1314: 'Date'
# Error in row 1315: 'Date'
# Error in row 1316: 'Date'
# Error in row 1317: 'Date'
# Error in row 1318: 'Date'
# Error in row 1319: 'Date'
# Error in row 1320: 'Date'
# Error in row 1321: 'Date'
# Error in row 1322: 'Date'
# Error in row 1323: 'Date'
# Error in row 1324: 'Date'
# Error in row 1325: 'Date'
# Error in row 1326: 'Date'
# Error in row 1327: 'Date'
# Error in row 1328: 'Date'
# Error in row 1329: 'Date'
# Error in row 1330: 'Date'
# Error in row 1331: 'Date'
# Error in row 1332: 'Date'
# Error in row 1333: 'Date'
# Error in row 1334: 'Date'
# Error in row 1335: 'Date'
# Error in row 1336: 'Date'
# Error in row 1337: 'Date'
# Error in row 1338: 'Date'
# Error in row 1339: 'Date'
# Error in row 1340: 'Date'
# Error in row 1341: 'Date'
# Error in row 1342: 'Date'
# Error in row 1343: 'Date'
# Error in row 1344: 'Date'
# Error in row 1345: 'Date'
# Error in row 1346: 'Date'
# Error in row 1347: 'Date'
# Error in row 1348: 'Date'
# Error in row 1349: 'Date'
# Error in row 1350: 'Date'
# Error in row 1351: 'Date'
# Error in row 1352: 'Date'
# Error in row 1353: 'Date'
# Error in row 1354: 'Date'
# Error in row 1355: 'Date'
# Error in row 1356: 'Date'
# Error in row 1357: 'Date'
# Error in row 1358: 'Date'
# Error in row 1359: 'Date'
# Error in row 1360: 'Date'
# Error in row 1361: 'Date'
# Error in row 1362: 'Date'
# Error in row 1363: 'Date'
# Error in row 1364: 'Date'
# Error in row 1365: 'Date'
# Error in row 1366: 'Date'
# Error in row 1367: 'Date'
# Error in row 1368: 'Date'
# Error in row 1369: 'Date'
# Error in row 1370: 'Date'
# Error in row 1371: 'Date'
# Error in row 1372: 'Date'
# Error in row 1373: 'Date'
# Error in row 1374: 'Date'
# Error in row 1375: 'Date'
# Error in row 1376: 'Date'
# Error in row 1377: 'Date'
# Error in row 1378: 'Date'
# Error in row 1379: 'Date'
# Error in row 1380: 'Date'
# Error in row 1381: 'Date'
# Error in row 1382: 'Date'
# Error in row 1383: 'Date'
# Error in row 1384: 'Date'
# Error in row 1385: 'Date'
# Error in row 1386: 'Date'
# Error in row 1387: 'Date'
# Error in row 1388: 'Date'
# Error in row 1389: 'Date'
# Error in row 1390: 'Date'
# Error in row 1391: 'Date'
# Error in row 1392: 'Date'
# Error in row 1393: 'Date'
# Error in row 1394: 'Date'
# Error in row 1395: 'Date'
# Error in row 1396: 'Date'
# Error in row 1397: 'Date'
# Error in row 1398: 'Date'
# Error in row 1399: 'Date'
# Error in row 1400: 'Date'
# Error in row 1401: 'Date'
# Error in row 1402: 'Date'
# Error in row 1403: 'Date'
# Error in row 1404: 'Date'
# Error in row 1405: 'Date'
# Error in row 1406: 'Date'
# Error in row 1407: 'Date'
# Error in row 1408: 'Date'
# Error in row 1409: 'Date'
# Error in row 1410: 'Date'
# Error in row 1411: 'Date'
# Error in row 1412: 'Date'
# Error in row 1413: 'Date'
# Error in row 1414: 'Date'
# Error in row 1415: 'Date'
# Error in row 1416: 'Date'
# Error in row 1417: 'Date'
# Error in row 1418: 'Date'
# Error in row 1419: 'Date'
# Error in row 1420: 'Date'
# Error in row 1421: 'Date'
# Error in row 1422: 'Date'
# Error in row 1423: 'Date'
# Error in row 1424: 'Date'
# Error in row 1425: 'Date'
# Error in row 1426: 'Date'
# Error in row 1427: 'Date'
# Error in row 1428: 'Date'
# Error in row 1429: 'Date'
# Error in row 1430: 'Date'
# Error in row 1431: 'Date'
# Error in row 1432: 'Date'
# Error in row 1433: 'Date'
# Error in row 1434: 'Date'
# Error in row 1435: 'Date'
# Error in row 1436: 'Date'
# Error in row 1437: 'Date'
# Error in row 1438: 'Date'
# Error in row 1439: 'Date'
# Error in row 1440: 'Date'
# Error in row 1441: 'Date'
# Error in row 1442: 'Date'
# Error in row 1443: 'Date'
# Error in row 1444: 'Date'
# Error in row 1445: 'Date'
# Error in row 1446: 'Date'
# Error in row 1447: 'Date'
# Error in row 1448: 'Date'
# Error in row 1449: 'Date'
# Error in row 1450: 'Date'
# Error in row 1451: 'Date'
# Error in row 1452: 'Date'
# Error in row 1453: 'Date'
# Error in row 1454: 'Date'
# Error in row 1455: 'Date'
# Error in row 1456: 'Date'
# Error in row 1457: 'Date'
# Error in row 1458: 'Date'
# Error in row 1459: 'Date'
# Error in row 1460: 'Date'
# Error in row 1461: 'Date'
# Error in row 1462: 'Date'
# Error in row 1463: 'Date'
# Error in row 1464: 'Date'
# Error in row 1465: 'Date'
# Error in row 1466: 'Date'
# Error in row 1467: 'Date'
# Error in row 1468: 'Date'
# Error in row 1469: 'Date'
# Error in row 1470: 'Date'
# Error in row 1471: 'Date'
# Error in row 1472: 'Date'
# Error in row 1473: 'Date'
# Error in row 1474: 'Date'
# Error in row 1475: 'Date'
# Error in row 1476: 'Date'
# Error in row 1477: 'Date'
# Error in row 1478: 'Date'
# Error in row 1479: 'Date'
# Error in row 1480: 'Date'
# Error in row 1481: 'Date'
# Error in row 1482: 'Date'
# Error in row 1483: 'Date'
# Error in row 1484: 'Date'
# Error in row 1485: 'Date'
# Error in row 1486: 'Date'
# Error in row 1487: 'Date'
# Error in row 1488: 'Date'
# Error in row 1489: 'Date'
# Error in row 1490: 'Date'
# Error in row 1491: 'Date'
# Error in row 1492: 'Date'
# Error in row 1493: 'Date'
# Error in row 1494: 'Date'
# Error in row 1495: 'Date'
# Error in row 1496: 'Date'
# Error in row 1497: 'Date'
# Error in row 1498: 'Date'
# Error in row 1499: 'Date'
# Error in row 1500: 'Date'
# Error in row 1501: 'Date'
# Error in row 1502: 'Date'
# Error in row 1503: 'Date'
# Error in row 1504: 'Date'
# Error in row 1505: 'Date'
# Error in row 1506: 'Date'
# Error in row 1507: 'Date'
# Error in row 1508: 'Date'
# Error in row 1509: 'Date'
# Error in row 1510: 'Date'
# Error in row 1511: 'Date'
# Error in row 1512: 'Date'
# Error in row 1513: 'Date'
# Error in row 1514: 'Date'
# Error in row 1515: 'Date'
# Error in row 1516: 'Date'
# Error in row 1517: 'Date'
# Error in row 1518: 'Date'
# Error in row 1519: 'Date'
# Error in row 1520: 'Date'
# Error in row 1521: 'Date'
# Error in row 1522: 'Date'
# Error in row 1523: 'Date'
# Error in row 1524: 'Date'
# Error in row 1525: 'Date'
# Error in row 1526: 'Date'
# Error in row 1527: 'Date'
# Error in row 1528: 'Date'
# Error in row 1529: 'Date'
# Error in row 1530: 'Date'
# Error in row 1531: 'Date'
# Error in row 1532: 'Date'
# Error in row 1533: 'Date'
# Error in row 1534: 'Date'
# Error in row 1535: 'Date'
# Error in row 1536: 'Date'
# Error in row 1537: 'Date'
# Error in row 1538: 'Date'
# Error in row 1539: 'Date'
# Error in row 1540: 'Date'
# Error in row 1541: 'Date'
# Error in row 1542: 'Date'
# Error in row 1543: 'Date'
# Error in row 1544: 'Date'
# Error in row 1545: 'Date'
# Error in row 1546: 'Date'
# Error in row 1547: 'Date'
# Error in row 1548: 'Date'
# Error in row 1549: 'Date'
# Error in row 1550: 'Date'
# Error in row 1551: 'Date'
# Error in row 1552: 'Date'
# Error in row 1553: 'Date'
# Error in row 1554: 'Date'
# Error in row 1555: 'Date'
# Error in row 1556: 'Date'
# Error in row 1557: 'Date'
# Error in row 1558: 'Date'
# Error in row 1559: 'Date'
# Error in row 1560: 'Date'
# Error in row 1561: 'Date'
# Error in row 1562: 'Date'
# Error in row 1563: 'Date'
# Error in row 1564: 'Date'
# Error in row 1565: 'Date'
# Error in row 1566: 'Date'
# Error in row 1567: 'Date'
# Error in row 1568: 'Date'
# Error in row 1569: 'Date'
# Error in row 1570: 'Date'
# Error in row 1571: 'Date'
# Error in row 1572: 'Date'
# Error in row 1573: 'Date'
# Error in row 1574: 'Date'
# Error in row 1575: 'Date'
# Error in row 1576: 'Date'
# Error in row 1577: 'Date'
# Error in row 1578: 'Date'
# Error in row 1579: 'Date'
# Error in row 1580: 'Date'
# Error in row 1581: 'Date'
# Error in row 1582: 'Date'
# Error in row 1583: 'Date'
# Error in row 1584: 'Date'
# Error in row 1585: 'Date'
# Error in row 1586: 'Date'
# Error in row 1587: 'Date'
# Error in row 1588: 'Date'
# Error in row 1589: 'Date'
# Error in row 1590: 'Date'
# Error in row 1591: 'Date'
# Error in row 1592: 'Date'
# Error in row 1593: 'Date'
# Error in row 1594: 'Date'
# Error in row 1595: 'Date'
# Error in row 1596: 'Date'
# Error in row 1597: 'Date'
# Error in row 1598: 'Date'
# Error in row 1599: 'Date'
# Error in row 1600: 'Date'
# Error in row 1601: 'Date'
# Error in row 1602: 'Date'
# Error in row 1603: 'Date'
# Error in row 1604: 'Date'
# Error in row 1605: 'Date'
# Error in row 1606: 'Date'
# Error in row 1607: 'Date'
# Error in row 1608: 'Date'
# Error in row 1609: 'Date'
# Error in row 1610: 'Date'
# Error in row 1611: 'Date'
# Error in row 1612: 'Date'
# Error in row 1613: 'Date'
# Error in row 1614: 'Date'
# Error in row 1615: 'Date'
# Error in row 1616: 'Date'
# Error in row 1617: 'Date'
# Error in row 1618: 'Date'
# Error in row 1619: 'Date'
# Error in row 1620: 'Date'
# Error in row 1621: 'Date'
# Error in row 1622: 'Date'
# Error in row 1623: 'Date'
# Error in row 1624: 'Date'
# Error in row 1625: 'Date'
# Error in row 1626: 'Date'
# Error in row 1627: 'Date'
# Error in row 1628: 'Date'
# Error in row 1629: 'Date'
# Error in row 1630: 'Date'
# Error in row 1631: 'Date'
# Error in row 1632: 'Date'
# Error in row 1633: 'Date'
# Error in row 1634: 'Date'
# Error in row 1635: 'Date'
# Error in row 1636: 'Date'
# Error in row 1637: 'Date'
# Error in row 1638: 'Date'
# Error in row 1639: 'Date'
# Error in row 1640: 'Date'
# Error in row 1641: 'Date'
# Error in row 1642: 'Date'
# Error in row 1643: 'Date'
# Error in row 1644: 'Date'
# Error in row 1645: 'Date'
# Error in row 1646: 'Date'
# Error in row 1647: 'Date'
# Error in row 1648: 'Date'
# Error in row 1649: 'Date'
# Error in row 1650: 'Date'
# Error in row 1651: 'Date'
# Error in row 1652: 'Date'
# Error in row 1653: 'Date'
# Error in row 1654: 'Date'
# Error in row 1655: 'Date'
# Error in row 1656: 'Date'
# Error in row 1657: 'Date'
# Error in row 1658: 'Date'
# Error in row 1659: 'Date'
# Error in row 1660: 'Date'
# Error in row 1661: 'Date'
# Error in row 1662: 'Date'
# Error in row 1663: 'Date'
# Error in row 1664: 'Date'
# Error in row 1665: 'Date'
# Error in row 1666: 'Date'
# Error in row 1667: 'Date'
# Error in row 1668: 'Date'
# Error in row 1669: 'Date'
# Error in row 1670: 'Date'
# Error in row 1671: 'Date'
# Error in row 1672: 'Date'
# Error in row 1673: 'Date'
# Error in row 1674: 'Date'
# Error in row 1675: 'Date'
# Error in row 1676: 'Date'
# Error in row 1677: 'Date'
# Error in row 1678: 'Date'
# Error in row 1679: 'Date'
# Error in row 1680: 'Date'
# Error in row 1681: 'Date'
# Error in row 1682: 'Date'
# Error in row 1683: 'Date'
# Error in row 1684: 'Date'
# Error in row 1685: 'Date'
# Error in row 1686: 'Date'
# Error in row 1687: 'Date'
# Error in row 1688: 'Date'
# Error in row 1689: 'Date'
# Error in row 1690: 'Date'
# Error in row 1691: 'Date'
# Error in row 1692: 'Date'
# Error in row 1693: 'Date'
# Error in row 1694: 'Date'
# Error in row 1695: 'Date'
# Error in row 1696: 'Date'
# Error in row 1697: 'Date'
# Error in row 1698: 'Date'
# Error in row 1699: 'Date'
# Error in row 1700: 'Date'
# Error in row 1701: 'Date'
# Error in row 1702: 'Date'
# Error in row 1703: 'Date'
# Error in row 1704: 'Date'
# Error in row 1705: 'Date'
# Error in row 1706: 'Date'
# Error in row 1707: 'Date'
# Error in row 1708: 'Date'
# Error in row 1709: 'Date'
# Error in row 1710: 'Date'
# Error in row 1711: 'Date'
# Error in row 1712: 'Date'
# Error in row 1713: 'Date'
# Error in row 1714: 'Date'
# Error in row 1715: 'Date'
# Error in row 1716: 'Date'
# Error in row 1717: 'Date'
# Error in row 1718: 'Date'
# Error in row 1719: 'Date'
# Error in row 1720: 'Date'
# Error in row 1721: 'Date'
# Error in row 1722: 'Date'
# Error in row 1723: 'Date'
# Error in row 1724: 'Date'
# Error in row 1725: 'Date'
# Error in row 1726: 'Date'
# Error in row 1727: 'Date'
# Error in row 1728: 'Date'
# Error in row 1729: 'Date'
# Error in row 1730: 'Date'
# Error in row 1731: 'Date'
# Error in row 1732: 'Date'
# Error in row 1733: 'Date'
# Error in row 1734: 'Date'
# Error in row 1735: 'Date'
# Error in row 1736: 'Date'
# Error in row 1737: 'Date'
# Error in row 1738: 'Date'
# Error in row 1739: 'Date'
# Error in row 1740: 'Date'
# Error in row 1741: 'Date'
# Error in row 1742: 'Date'
# Error in row 1743: 'Date'
# Error in row 1744: 'Date'
# Error in row 1745: 'Date'
# Error in row 1746: 'Date'
# Error in row 1747: 'Date'
# Error in row 1748: 'Date'
# Error in row 1749: 'Date'
# Error in row 1750: 'Date'
# Error in row 1751: 'Date'
# Error in row 1752: 'Date'
# Error in row 1753: 'Date'
# Error in row 1754: 'Date'
# Error in row 1755: 'Date'
# Error in row 1756: 'Date'
# Error in row 1757: 'Date'
# Error in row 1758: 'Date'
# Error in row 1759: 'Date'
# Error in row 1760: 'Date'
# Error in row 1761: 'Date'
# Error in row 1762: 'Date'
# Error in row 1763: 'Date'
# Error in row 1764: 'Date'
# Error in row 1765: 'Date'
# Error in row 1766: 'Date'
# Error in row 1767: 'Date'
# Error in row 1768: 'Date'
# Error in row 1769: 'Date'
# Error in row 1770: 'Date'
# Error in row 1771: 'Date'
# Error in row 1772: 'Date'
# Error in row 1773: 'Date'
# Error in row 1774: 'Date'
# Error in row 1775: 'Date'
# Error in row 1776: 'Date'
# Error in row 1777: 'Date'
# Error in row 1778: 'Date'
# Error in row 1779: 'Date'
# Error in row 1780: 'Date'
# Error in row 1781: 'Date'
# Error in row 1782: 'Date'
# Error in row 1783: 'Date'
# Error in row 1784: 'Date'
# Error in row 1785: 'Date'
# Error in row 1786: 'Date'
# Error in row 1787: 'Date'
# Error in row 1788: 'Date'
# Error in row 1789: 'Date'
# Error in row 1790: 'Date'
# Error in row 1791: 'Date'
# Error in row 1792: 'Date'
# Error in row 1793: 'Date'
# Error in row 1794: 'Date'
# Error in row 1795: 'Date'
# Error in row 1796: 'Date'
# Error in row 1797: 'Date'
# Error in row 1798: 'Date'
# Error in row 1799: 'Date'
# Error in row 1800: 'Date'
# Error in row 1801: 'Date'
# Error in row 1802: 'Date'
# Error in row 1803: 'Date'
# Error in row 1804: 'Date'
# Error in row 1805: 'Date'
# Error in row 1806: 'Date'
# Error in row 1807: 'Date'
# Error in row 1808: 'Date'
# Error in row 1809: 'Date'
# Error in row 1810: 'Date'
# Error in row 1811: 'Date'
# Error in row 1812: 'Date'
# Error in row 1813: 'Date'
# Error in row 1814: 'Date'
# Error in row 1815: 'Date'
# Error in row 1816: 'Date'
# Error in row 1817: 'Date'
# Error in row 1818: 'Date'
# Error in row 1819: 'Date'
# Error in row 1820: 'Date'
# Error in row 1821: 'Date'
# Error in row 1822: 'Date'
# Error in row 1823: 'Date'
# Error in row 1824: 'Date'
# Error in row 1825: 'Date'
# Error in row 1826: 'Date'
# Error in row 1827: 'Date'
# Error in row 1828: 'Date'
# Error in row 1829: 'Date'
# Error in row 1830: 'Date'
# Error in row 1831: 'Date'
# Error in row 1832: 'Date'
# Error in row 1833: 'Date'
# Error in row 1834: 'Date'
# Error in row 1835: 'Date'
# Error in row 1836: 'Date'
# Error in row 1837: 'Date'
# Error in row 1838: 'Date'
# Error in row 1839: 'Date'
# Error in row 1840: 'Date'
# Error in row 1841: 'Date'
# Error in row 1842: 'Date'
# Error in row 1843: 'Date'
# Error in row 1844: 'Date'
# Error in row 1845: 'Date'
# Error in row 1846: 'Date'
# Error in row 1847: 'Date'
# Error in row 1848: 'Date'
# Error in row 1849: 'Date'
# Error in row 1850: 'Date'
# Error in row 1851: 'Date'
# Error in row 1852: 'Date'
# Error in row 1853: 'Date'
# Error in row 1854: 'Date'
# Error in row 1855: 'Date'
# Error in row 1856: 'Date'
# Error in row 1857: 'Date'
# Error in row 1858: 'Date'
# Error in row 1859: 'Date'
# Error in row 1860: 'Date'
# Error in row 1861: 'Date'
# Error in row 1862: 'Date'
# Error in row 1863: 'Date'
# Error in row 1864: 'Date'
# Error in row 1865: 'Date'
# Error in row 1866: 'Date'
# Error in row 1867: 'Date'
# Error in row 1868: 'Date'
# Error in row 1869: 'Date'
# Error in row 1870: 'Date'
# Error in row 1871: 'Date'
# Error in row 1872: 'Date'
# Error in row 1873: 'Date'
# Error in row 1874: 'Date'
# Error in row 1875: 'Date'
# Error in row 1876: 'Date'
# Error in row 1877: 'Date'
# Error in row 1878: 'Date'
# Error in row 1879: 'Date'
# Error in row 1880: 'Date'
# Error in row 1881: 'Date'
# Error in row 1882: 'Date'
# Error in row 1883: 'Date'
# Error in row 1884: 'Date'
# Error in row 1885: 'Date'
# Error in row 1886: 'Date'
# Error in row 1887: 'Date'
# ...
# Error in row 99416: 'Date'
# Error in row 99417: 'Date'
# Error in row 99418: 'Date'
# Error in row 99419: 'Date'
# Error in row 99420: 'Date'
# Error in row 99421: 'Date'
# Error in row 99422: 'Date'
# Error in row 99423: 'Date'
# Error in row 99424: 'Date'
# Error in row 99425: 'Date'
# Error in row 99426: 'Date'
# Error in row 99427: 'Date'
# Error in row 99428: 'Date'
# Error in row 99429: 'Date'
# Error in row 99430: 'Date'
# Error in row 99431: 'Date'
# Error in row 99432: 'Date'
# Error in row 99433: 'Date'
# Error in row 99434: 'Date'
# Error in row 99435: 'Date'
# Error in row 99436: 'Date'
# Error in row 99437: 'Date'
# Error in row 99438: 'Date'
# Error in row 99439: 'Date'
# Error in row 99440: 'Date'
# Error in row 99441: 'Date'
# Error in row 99442: 'Date'
# Error in row 99443: 'Date'
# Error in row 99444: 'Date'
# Error in row 99445: 'Date'
# Error in row 99446: 'Date'
# Error in row 99447: 'Date'
# Error in row 99448: 'Date'
# Error in row 99449: 'Date'
# Error in row 99450: 'Date'
# Error in row 99451: 'Date'
# Error in row 99452: 'Date'
# Error in row 99453: 'Date'
# Error in row 99454: 'Date'
# Error in row 99455: 'Date'
# Error in row 99456: 'Date'
# Error in row 99457: 'Date'
# Error in row 99458: 'Date'
# Error in row 99459: 'Date'
# Error in row 99460: 'Date'
# Error in row 99461: 'Date'
# Error in row 99462: 'Date'
# Error in row 99463: 'Date'
# Error in row 99464: 'Date'
# Error in row 99465: 'Date'
# Error in row 99466: 'Date'
# Error in row 99467: 'Date'
# Error in row 99468: 'Date'
# Error in row 99469: 'Date'
# Error in row 99470: 'Date'
# Error in row 99471: 'Date'
# Error in row 99472: 'Date'
# Error in row 99473: 'Date'
# Error in row 99474: 'Date'
# Error in row 99475: 'Date'
# Error in row 99476: 'Date'
# Error in row 99477: 'Date'
# Error in row 99478: 'Date'
# Error in row 99479: 'Date'
# Error in row 99480: 'Date'
# Error in row 99481: 'Date'
# Error in row 99482: 'Date'
# Error in row 99483: 'Date'
# Error in row 99484: 'Date'
# Error in row 99485: 'Date'
# Error in row 99486: 'Date'
# Error in row 99487: 'Date'
# Error in row 99488: 'Date'
# Error in row 99489: 'Date'
# Error in row 99490: 'Date'
# Error in row 99491: 'Date'
# Error in row 99492: 'Date'
# Error in row 99493: 'Date'
# Error in row 99494: 'Date'
# Error in row 99495: 'Date'
# Error in row 99496: 'Date'
# Error in row 99497: 'Date'
# Error in row 99498: 'Date'
# Error in row 99499: 'Date'
# Error in row 99500: 'Date'
# Error in row 99501: 'Date'
# Error in row 99502: 'Date'
# Error in row 99503: 'Date'
# Error in row 99504: 'Date'
# Error in row 99505: 'Date'
# Error in row 99506: 'Date'
# Error in row 99507: 'Date'
# Error in row 99508: 'Date'
# Error in row 99509: 'Date'
# Error in row 99510: 'Date'
# Error in row 99511: 'Date'
# Error in row 99512: 'Date'
# Error in row 99513: 'Date'
# Error in row 99514: 'Date'
# Error in row 99515: 'Date'
# Error in row 99516: 'Date'
# Error in row 99517: 'Date'
# Error in row 99518: 'Date'
# Error in row 99519: 'Date'
# Error in row 99520: 'Date'
# Error in row 99521: 'Date'
# Error in row 99522: 'Date'
# Error in row 99523: 'Date'
# Error in row 99524: 'Date'
# Error in row 99525: 'Date'
# Error in row 99526: 'Date'
# Error in row 99527: 'Date'
# Error in row 99528: 'Date'
# Error in row 99529: 'Date'
# Error in row 99530: 'Date'
# Error in row 99531: 'Date'
# Error in row 99532: 'Date'
# Error in row 99533: 'Date'
# Error in row 99534: 'Date'
# Error in row 99535: 'Date'
# Error in row 99536: 'Date'
# Error in row 99537: 'Date'
# Error in row 99538: 'Date'
# Error in row 99539: 'Date'
# Error in row 99540: 'Date'
# Error in row 99541: 'Date'
# Error in row 99542: 'Date'
# Error in row 99543: 'Date'
# Error in row 99544: 'Date'
# Error in row 99545: 'Date'
# Error in row 99546: 'Date'
# Error in row 99547: 'Date'
# Error in row 99548: 'Date'
# Error in row 99549: 'Date'
# Error in row 99550: 'Date'
# Error in row 99551: 'Date'
# Error in row 99552: 'Date'
# Error in row 99553: 'Date'
# Error in row 99554: 'Date'
# Error in row 99555: 'Date'
# Error in row 99556: 'Date'
# Error in row 99557: 'Date'
# Error in row 99558: 'Date'
# Error in row 99559: 'Date'
# Error in row 99560: 'Date'
# Error in row 99561: 'Date'
# Error in row 99562: 'Date'
# Error in row 99563: 'Date'
# Error in row 99564: 'Date'
# Error in row 99565: 'Date'
# Error in row 99566: 'Date'
# Error in row 99567: 'Date'
# Error in row 99568: 'Date'
# Error in row 99569: 'Date'
# Error in row 99570: 'Date'
# Error in row 99571: 'Date'
# Error in row 99572: 'Date'
# Error in row 99573: 'Date'
# Error in row 99574: 'Date'
# Error in row 99575: 'Date'
# Error in row 99576: 'Date'
# Error in row 99577: 'Date'
# Error in row 99578: 'Date'
# Error in row 99579: 'Date'
# Error in row 99580: 'Date'
# Error in row 99581: 'Date'
# Error in row 99582: 'Date'
# Error in row 99583: 'Date'
# Error in row 99584: 'Date'
# Error in row 99585: 'Date'
# Error in row 99586: 'Date'
# Error in row 99587: 'Date'
# Error in row 99588: 'Date'
# Error in row 99589: 'Date'
# Error in row 99590: 'Date'
# Error in row 99591: 'Date'
# Error in row 99592: 'Date'
# Error in row 99593: 'Date'
# Error in row 99594: 'Date'
# Error in row 99595: 'Date'
# Error in row 99596: 'Date'
# Error in row 99597: 'Date'
# Error in row 99598: 'Date'
# Error in row 99599: 'Date'
# Error in row 99600: 'Date'
# Error in row 99601: 'Date'
# Error in row 99602: 'Date'
# Error in row 99603: 'Date'
# Error in row 99604: 'Date'
# Error in row 99605: 'Date'
# Error in row 99606: 'Date'
# Error in row 99607: 'Date'
# Error in row 99608: 'Date'
# Error in row 99609: 'Date'
# Error in row 99610: 'Date'
# Error in row 99611: 'Date'
# Error in row 99612: 'Date'
# Error in row 99613: 'Date'
# Error in row 99614: 'Date'
# Error in row 99615: 'Date'
# Error in row 99616: 'Date'
# Error in row 99617: 'Date'
# Error in row 99618: 'Date'
# Error in row 99619: 'Date'
# Error in row 99620: 'Date'
# Error in row 99621: 'Date'
# Error in row 99622: 'Date'
# Error in row 99623: 'Date'
# Error in row 99624: 'Date'
# Error in row 99625: 'Date'
# Error in row 99626: 'Date'
# Error in row 99627: 'Date'
# Error in row 99628: 'Date'
# Error in row 99629: 'Date'
# Error in row 99630: 'Date'
# Error in row 99631: 'Date'
# Error in row 99632: 'Date'
# Error in row 99633: 'Date'
# Error in row 99634: 'Date'
# Error in row 99635: 'Date'
# Error in row 99636: 'Date'
# Error in row 99637: 'Date'
# Error in row 99638: 'Date'
# Error in row 99639: 'Date'
# Error in row 99640: 'Date'
# Error in row 99641: 'Date'
# Error in row 99642: 'Date'
# Error in row 99643: 'Date'
# Error in row 99644: 'Date'
# Error in row 99645: 'Date'
# Error in row 99646: 'Date'
# Error in row 99647: 'Date'
# Error in row 99648: 'Date'
# Error in row 99649: 'Date'
# Error in row 99650: 'Date'
# Error in row 99651: 'Date'
# Error in row 99652: 'Date'
# Error in row 99653: 'Date'
# Error in row 99654: 'Date'
# Error in row 99655: 'Date'
# Error in row 99656: 'Date'
# Error in row 99657: 'Date'
# Error in row 99658: 'Date'
# Error in row 99659: 'Date'
# Error in row 99660: 'Date'
# Error in row 99661: 'Date'
# Error in row 99662: 'Date'
# Error in row 99663: 'Date'
# Error in row 99664: 'Date'
# Error in row 99665: 'Date'
# Error in row 99666: 'Date'
# Error in row 99667: 'Date'
# Error in row 99668: 'Date'
# Error in row 99669: 'Date'
# Error in row 99670: 'Date'
# Error in row 99671: 'Date'
# Error in row 99672: 'Date'
# Error in row 99673: 'Date'
# Error in row 99674: 'Date'
# Error in row 99675: 'Date'
# Error in row 99676: 'Date'
# Error in row 99677: 'Date'
# Error in row 99678: 'Date'
# Error in row 99679: 'Date'
# Error in row 99680: 'Date'
# Error in row 99681: 'Date'
# Error in row 99682: 'Date'
# Error in row 99683: 'Date'
# Error in row 99684: 'Date'
# Error in row 99685: 'Date'
# Error in row 99686: 'Date'
# Error in row 99687: 'Date'
# Error in row 99688: 'Date'
# Error in row 99689: 'Date'
# Error in row 99690: 'Date'
# Error in row 99691: 'Date'
# Error in row 99692: 'Date'
# Error in row 99693: 'Date'
# Error in row 99694: 'Date'
# Error in row 99695: 'Date'
# Error in row 99696: 'Date'
# Error in row 99697: 'Date'
# Error in row 99698: 'Date'
# Error in row 99699: 'Date'
# Error in row 99700: 'Date'
# Error in row 99701: 'Date'
# Error in row 99702: 'Date'
# Error in row 99703: 'Date'
# Error in row 99704: 'Date'
# Error in row 99705: 'Date'
# Error in row 99706: 'Date'
# Error in row 99707: 'Date'
# Error in row 99708: 'Date'
# Error in row 99709: 'Date'
# Error in row 99710: 'Date'
# Error in row 99711: 'Date'
# Error in row 99712: 'Date'
# Error in row 99713: 'Date'
# Error in row 99714: 'Date'
# Error in row 99715: 'Date'
# Error in row 99716: 'Date'
# Error in row 99717: 'Date'
# Error in row 99718: 'Date'
# Error in row 99719: 'Date'
# Error in row 99720: 'Date'
# Error in row 99721: 'Date'
# Error in row 99722: 'Date'
# Error in row 99723: 'Date'
# Error in row 99724: 'Date'
# Error in row 99725: 'Date'
# Error in row 99726: 'Date'
# Error in row 99727: 'Date'
# Error in row 99728: 'Date'
# Error in row 99729: 'Date'
# Error in row 99730: 'Date'
# Error in row 99731: 'Date'
# Error in row 99732: 'Date'
# Error in row 99733: 'Date'
# Error in row 99734: 'Date'
# Error in row 99735: 'Date'
# Error in row 99736: 'Date'
# Error in row 99737: 'Date'
# Error in row 99738: 'Date'
# Error in row 99739: 'Date'
# Error in row 99740: 'Date'
# Error in row 99741: 'Date'
# Error in row 99742: 'Date'
# Error in row 99743: 'Date'
# Error in row 99744: 'Date'
# Error in row 99745: 'Date'
# Error in row 99746: 'Date'
# Error in row 99747: 'Date'
# Error in row 99748: 'Date'
# Error in row 99749: 'Date'
# Error in row 99750: 'Date'
# Error in row 99751: 'Date'
# Error in row 99752: 'Date'
# Error in row 99753: 'Date'
# Error in row 99754: 'Date'
# Error in row 99755: 'Date'
# Error in row 99756: 'Date'
# Error in row 99757: 'Date'
# Error in row 99758: 'Date'
# Error in row 99759: 'Date'
# Error in row 99760: 'Date'
# Error in row 99761: 'Date'
# Error in row 99762: 'Date'
# Error in row 99763: 'Date'
# Error in row 99764: 'Date'
# Error in row 99765: 'Date'
# Error in row 99766: 'Date'
# Error in row 99767: 'Date'
# Error in row 99768: 'Date'
# Error in row 99769: 'Date'
# Error in row 99770: 'Date'
# Error in row 99771: 'Date'
# Error in row 99772: 'Date'
# Error in row 99773: 'Date'
# Error in row 99774: 'Date'
# Error in row 99775: 'Date'
# Error in row 99776: 'Date'
# Error in row 99777: 'Date'
# Error in row 99778: 'Date'
# Error in row 99779: 'Date'
# Error in row 99780: 'Date'
# Error in row 99781: 'Date'
# Error in row 99782: 'Date'
# Error in row 99783: 'Date'
# Error in row 99784: 'Date'
# Error in row 99785: 'Date'
# Error in row 99786: 'Date'
# Error in row 99787: 'Date'
# Error in row 99788: 'Date'
# Error in row 99789: 'Date'
# Error in row 99790: 'Date'
# Error in row 99791: 'Date'
# Error in row 99792: 'Date'
# Error in row 99793: 'Date'
# Error in row 99794: 'Date'
# Error in row 99795: 'Date'
# Error in row 99796: 'Date'
# Error in row 99797: 'Date'
# Error in row 99798: 'Date'
# Error in row 99799: 'Date'
# Error in row 99800: 'Date'
# Error in row 99801: 'Date'
# Error in row 99802: 'Date'
# Error in row 99803: 'Date'
# Error in row 99804: 'Date'
# Error in row 99805: 'Date'
# Error in row 99806: 'Date'
# Error in row 99807: 'Date'
# Error in row 99808: 'Date'
# Error in row 99809: 'Date'
# Error in row 99810: 'Date'
# Error in row 99811: 'Date'
# Error in row 99812: 'Date'
# Error in row 99813: 'Date'
# Error in row 99814: 'Date'
# Error in row 99815: 'Date'
# Error in row 99816: 'Date'
# Error in row 99817: 'Date'
# Error in row 99818: 'Date'
# Error in row 99819: 'Date'
# Error in row 99820: 'Date'
# Error in row 99821: 'Date'
# Error in row 99822: 'Date'
# Error in row 99823: 'Date'
# Error in row 99824: 'Date'
# Error in row 99825: 'Date'
# Error in row 99826: 'Date'
# Error in row 99827: 'Date'
# Error in row 99828: 'Date'
# Error in row 99829: 'Date'
# Error in row 99830: 'Date'
# Error in row 99831: 'Date'
# Error in row 99832: 'Date'
# Error in row 99833: 'Date'
# Error in row 99834: 'Date'
# Error in row 99835: 'Date'
# Error in row 99836: 'Date'
# Error in row 99837: 'Date'
# Error in row 99838: 'Date'
# Error in row 99839: 'Date'
# Error in row 99840: 'Date'
# Error in row 99841: 'Date'
# Error in row 99842: 'Date'
# Error in row 99843: 'Date'
# Error in row 99844: 'Date'
# Error in row 99845: 'Date'
# Error in row 99846: 'Date'
# Error in row 99847: 'Date'
# Error in row 99848: 'Date'
# Error in row 99849: 'Date'
# Error in row 99850: 'Date'
# Error in row 99851: 'Date'
# Error in row 99852: 'Date'
# Error in row 99853: 'Date'
# Error in row 99854: 'Date'
# Error in row 99855: 'Date'
# Error in row 99856: 'Date'
# Error in row 99857: 'Date'
# Error in row 99858: 'Date'
# Error in row 99859: 'Date'
# Error in row 99860: 'Date'
# Error in row 99861: 'Date'
# Error in row 99862: 'Date'
# Error in row 99863: 'Date'
# Error in row 99864: 'Date'
# Error in row 99865: 'Date'
# Error in row 99866: 'Date'
# Error in row 99867: 'Date'
# Error in row 99868: 'Date'
# Error in row 99869: 'Date'
# Error in row 99870: 'Date'
# Error in row 99871: 'Date'
# Error in row 99872: 'Date'
# Error in row 99873: 'Date'
# Error in row 99874: 'Date'
# Error in row 99875: 'Date'
# Error in row 99876: 'Date'
# Error in row 99877: 'Date'
# Error in row 99878: 'Date'
# Error in row 99879: 'Date'
# Error in row 99880: 'Date'
# Error in row 99881: 'Date'
# Error in row 99882: 'Date'
# Error in row 99883: 'Date'
# Error in row 99884: 'Date'
# Error in row 99885: 'Date'
# Error in row 99886: 'Date'
# Error in row 99887: 'Date'
# Error in row 99888: 'Date'
# Error in row 99889: 'Date'
# Error in row 99890: 'Date'
# Error in row 99891: 'Date'
# Error in row 99892: 'Date'
# Error in row 99893: 'Date'
# Error in row 99894: 'Date'
# Error in row 99895: 'Date'
# Error in row 99896: 'Date'
# Error in row 99897: 'Date'
# Error in row 99898: 'Date'
# Error in row 99899: 'Date'
# Error in row 99900: 'Date'
# Error in row 99901: 'Date'
# Error in row 99902: 'Date'
# Error in row 99903: 'Date'
# Error in row 99904: 'Date'
# Error in row 99905: 'Date'
# Error in row 99906: 'Date'
# Error in row 99907: 'Date'
# Error in row 99908: 'Date'
# Error in row 99909: 'Date'
# Error in row 99910: 'Date'
# Error in row 99911: 'Date'
# Error in row 99912: 'Date'
# Error in row 99913: 'Date'
# Error in row 99914: 'Date'
# Error in row 99915: 'Date'
# Error in row 99916: 'Date'
# Error in row 99917: 'Date'
# Error in row 99918: 'Date'
# Error in row 99919: 'Date'
# Error in row 99920: 'Date'
# Error in row 99921: 'Date'
# Error in row 99922: 'Date'
# Error in row 99923: 'Date'
# Error in row 99924: 'Date'
# Error in row 99925: 'Date'
# Error in row 99926: 'Date'
# Error in row 99927: 'Date'
# Error in row 99928: 'Date'
# Error in row 99929: 'Date'
# Error in row 99930: 'Date'
# Error in row 99931: 'Date'
# Error in row 99932: 'Date'
# Error in row 99933: 'Date'
# Error in row 99934: 'Date'
# Error in row 99935: 'Date'
# Error in row 99936: 'Date'
# Error in row 99937: 'Date'
# Error in row 99938: 'Date'
# Error in row 99939: 'Date'
# Error in row 99940: 'Date'
# Error in row 99941: 'Date'
# Error in row 99942: 'Date'
# Error in row 99943: 'Date'
# Error in row 99944: 'Date'
# Error in row 99945: 'Date'
# Error in row 99946: 'Date'
# Error in row 99947: 'Date'
# Error in row 99948: 'Date'
# Error in row 99949: 'Date'
# Error in row 99950: 'Date'
# Error in row 99951: 'Date'
# Error in row 99952: 'Date'
# Error in row 99953: 'Date'
# Error in row 99954: 'Date'
# Error in row 99955: 'Date'
# Error in row 99956: 'Date'
# Error in row 99957: 'Date'
# Error in row 99958: 'Date'
# Error in row 99959: 'Date'
# Error in row 99960: 'Date'
# Error in row 99961: 'Date'
# Error in row 99962: 'Date'
# Error in row 99963: 'Date'
# Error in row 99964: 'Date'
# Error in row 99965: 'Date'
# Error in row 99966: 'Date'
# Error in row 99967: 'Date'
# Error in row 99968: 'Date'
# Error in row 99969: 'Date'
# Error in row 99970: 'Date'
# Error in row 99971: 'Date'
# Error in row 99972: 'Date'
# Error in row 99973: 'Date'
# Error in row 99974: 'Date'
# Error in row 99975: 'Date'
# Error in row 99976: 'Date'
# Error in row 99977: 'Date'
# Error in row 99978: 'Date'
# Error in row 99979: 'Date'
# Error in row 99980: 'Date'
# Error in row 99981: 'Date'
# Error in row 99982: 'Date'
# Error in row 99983: 'Date'
# Error in row 99984: 'Date'
# Error in row 99985: 'Date'
# Error in row 99986: 'Date'
# Error in row 99987: 'Date'
# Error in row 99988: 'Date'
# Error in row 99989: 'Date'
# Error in row 99990: 'Date'
# Error in row 99991: 'Date'
# Error in row 99992: 'Date'
# Error in row 99993: 'Date'
# Error in row 99994: 'Date'
# Error in row 99995: 'Date'
# Error in row 99996: 'Date'
# Error in row 99997: 'Date'
# Error in row 99998: 'Date'
# Error in row 99999: 'Date'
# Error in row 100000: 'Date'
# Successfully created 0 transactions (100000 errors)
#
# No transactions were loaded. Please check:
# 1. The file path is correct
# 2. The CSV file contains data
# 3. The column names match the expected format

# %% [markdown]
# **5: Quick Profiling**

# %%
# Price statistics
prices = [t.price for t in transactions]
print(f"Min price: {min(prices)}")
print(f"Mean price: {sum(prices)/len(prices):.2f}")
print(f"Max price: {max(prices)}")

# Unique cities
unique_cities = {t.shipping_city for t in transactions}
print(f"Unique cities count: {len(unique_cities)}")

# %% [markdown]
# **6: Spot the Grime**

# %%
# Find dirty data cases
dirty_cases = {
    "Missing coupon codes": sum(1 for t in transactions if not t.coupon_code),
    "Zero prices": sum(1 for t in transactions if t.price == 0),
    "Invalid dates": sum(1 for t in transactions if not pd.to_datetime(t.date, errors='coerce'))
}

print("Dirty data cases found:")
for case, count in dirty_cases.items():
    print(f"- {case}: {count}")

# %% [markdown]
# **7: Cleaning Rules**

# %%
def clean_transactions(transactions: List[Transaction]) -> List[Transaction]:
    """Apply cleaning rules to transaction data"""
    cleaned = []
    
    for t in transactions:
        try:
            # Rule 1: Fill missing coupon codes with 'NO_COUPON'
            coupon = t.coupon_code if t.coupon_code else 'NO_COUPON'
            
            # Rule 2: Remove transactions with zero prices
            if t.price <= 0:
                continue
                
            # Rule 3: Convert date to standard format
            date = pd.to_datetime(t.date).strftime('%Y-%m-%d')
            
            # Create cleaned transaction
            cleaned_t = Transaction(
                date=date,
                customer_id=t.customer_id,
                product=t.product,
                price=t.price,
                quantity=t.quantity,
                coupon_code=coupon,
                shipping_city=t.shipping_city.title()  # Rule 4: Standardize city names
            )
            cleaned.append(cleaned_t)
        except Exception as e:
            print(f"Skipping transaction {t} due to error: {e}")
    
    print(f"Cleaning complete. Kept {len(cleaned)} of {len(transactions)} transactions.")
    return cleaned

cleaned_transactions = clean_transactions(transactions)

# %% [markdown]
# **8: Transformations**

# %%
# Load secondary data (coupon metadata)
coupon_data = {
    'SUMMER20': 0.2,
    'WINTER15': 0.15,
    'SPRING10': 0.1,
    'NO_COUPON': 0.0
}

def apply_transformations(transactions: List[Transaction]) -> List[Transaction]:
    """Apply business transformations to data"""
    transformed = []
    
    for t in transactions:
        # Add discount percentage from coupon code
        discount = coupon_data.get(t.coupon_code, 0.0)
        
        # Calculate discounted price
        discounted_price = t.price * (1 - discount)
        
        # Create new transaction with additional fields
        new_t = Transaction(
            date=t.date,
            customer_id=t.customer_id,
            product=t.product,
            price=discounted_price,
            quantity=t.quantity,
            coupon_code=t.coupon_code,
            shipping_city=t.shipping_city
        )
        
        # Add new attributes (Python allows this despite type hints)
        new_t.discount_pct = discount
        new_t.original_price = t.price
        new_t.total = discounted_price * t.quantity
        
        transformed.append(new_t)
    
    return transformed

transformed_transactions = apply_transformations(cleaned_transactions)

# %% [markdown]
# **9: Feature Engineering**

# %%
from datetime import datetime

def add_features(transactions: List[Transaction]) -> List[Transaction]:
    """Add derived features to transactions"""
    enhanced = []
    latest_date = max(pd.to_datetime(t.date) for t in transactions)
    
    for t in transactions:
        # Add days since purchase
        purchase_date = pd.to_datetime(t.date)
        days_since = (latest_date - purchase_date).days
        
        # Add product category (simple extraction)
        category = t.product.split()[0]  # First word as category
        
        # Add to transaction
        t.days_since_purchase = days_since
        t.product_category = category
        enhanced.append(t)
    
    return enhanced

final_transactions = add_features(transformed_transactions)

# %% [markdown]
# **10: Mini-Aggregation**

# %%
# Revenue per shipping city
revenue_by_city = {}

for t in final_transactions:
    if t.shipping_city not in revenue_by_city:
        revenue_by_city[t.shipping_city] = 0
    revenue_by_city[t.shipping_city] += t.total

# Convert to DataFrame for nice display
revenue_df = pd.DataFrame.from_dict(revenue_by_city, orient='index', columns=['Revenue'])
revenue_df.sort_values('Revenue', ascending=False).head(10)

# %% [markdown]
# **11: Serialization Checkpoint**

# %%
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Convert to dict list for JSON
transactions_dict = [t.__dict__ for t in final_transactions]

# Save to JSON
with open('../data/transactions_clean.json', 'w') as f:
    json.dump(transactions_dict, f, indent=2)

# Save to Parquet
df = pd.DataFrame(transactions_dict)
table = pa.Table.from_pandas(df)
pq.write_table(table, '../data/transactions_clean.parquet')

print("Data saved to JSON and Parquet formats")

# %% [markdown]
# **12: Soft Interview Reflection**

# %% [markdown]
# **How OOP Helped**
#
# Using object-oriented programming (OOP) provided several benefits:
#
# 1. **Data Validation**: The Transaction class constructor automatically validated prices and quantities
# 2. **Organization**: All transaction-related logic stayed together in one place
# 3. **Extensibility**: Adding new features like discount calculation was easy by extending the class
# 4. **Readability**: Code using Transaction objects is more readable than raw dictionaries
#
# The class served as a single source of truth for what constitutes a valid transaction in our system.

# %% [markdown]
# ### Data-Dictionary Section

# %% [markdown]
# | Field | Type | Description | Source |
# |-------|------|-------------|--------|
# | date | string | Date of transaction (YYYY-MM-DD) | Primary |
# | customer_id | string | Unique customer identifier | Primary |
# | product | string | Product name | Primary |
# | price | float | Unit price before discounts | Primary |
# | quantity | integer | Number of units purchased | Primary |
# | coupon_code | string | Discount coupon applied | Primary |
# | shipping_city | string | Destination city for shipment | Primary |
# | discount_pct | float | Discount percentage (0.0-1.0) | Secondary (coupon metadata) |
# | original_price | float | Price before discounts | Calculated |
# | total | float | Final amount paid (price × quantity after discount) | Calculated |
# | days_since_purchase | integer | Days between transaction and latest date in data | Calculated |
# | product_category | string | Broad product category | Derived from product name |
